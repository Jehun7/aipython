# %%
#1
print("부산대학교")
print("기초교육원")
print("컴퓨팅적 사고와 코딩")
# Out:
# 부산대학교
# 기초교육원
# 컴퓨팅적 사고와 코딩

# %%
print('부산대학교') #첫째줄에 부산대학교를 출력합니다.
print('기초교육원') #둘째줄에 기초교육원을 출력합니다.
print('컴퓨팅적 사고와 코딩') #셋째줄에 컴퓨팅적사고와 코딩을 출력합니다.
# Out:
# 부산대학교
# 기초교육원
# 컴퓨팅적 사고와 코딩

# %%
print("""One
Two
Three""")
# Out:
# One
# Two
# Three

# %%
Lab=105
print('우리가 수업하는 실습실:')
print(Lab)
# Out:
# 우리가 수업하는 실습실:
# 105

# %%
Lab = 105
print('우리가 수업하는 실습실 :',Lab)
# Out:
# 우리가 수업하는 실습실 : 105

# %%
my_id = 202005153
grade = 2
print('나의 학번 : ')
print(my_id)
print('학년 : ')
print(grade)
# Out:
# 나의 학번 :
# 202005153
# 학년 :
# 2

# %%
dollars = 2.75
print('I have', dollars,' in my account.')
dollars = 99.95
print('But now I have', dollars,' in my account!')
# Out:
# I have 2.75  in my account.
# But now I have 99.95  in my account!

# %%
#2-10 (string_variable.py)
department = '정치외교학과'
name = '노제훈'
print(department, name)
# Out:
# 정치외교학과 홍길동

# %%
department = input('학과명: ')
name = input('성명: ')

# %% [markdown]
# 파이썬 코드에 작성해서 깃허브에 올리기
# yy-mm-dd.py로 깃허브에 올리기
